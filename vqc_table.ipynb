# %% [markdown]
# Running this code will create a dataframe with all the VQC results, by pulling the data from the VQC_Results folder

# %%
import pandas as pd
import glob
import os

# Get all prediction CSV files
prediction_files = glob.glob("VQC_Results/predictions_*.csv")

results = []

for file in prediction_files:
    basename = os.path.basename(file)
    parts = basename.replace("predictions_", "").replace(".csv", "").split("_")
    
    # Extract parameters
    fm_type = parts[0]  # Z or ZZ
    fm_reps = parts[1].replace("r", "")  # 1 or 2
    ans_name = parts[2]  # RealAmps, TwoLocal, EffSU2
    ans_reps = parts[3].replace("r", "")  # 1 or 2
    opt_name = parts[4]  # COBYLA300 or SPSA500
    
    # Read the CSV and calculate accuracy
    df = pd.read_csv(file)
    accuracy = df['Correct'].mean() * 100  # Convert to percentage
    
    results.append({
        'Feature Map': fm_type,
        'FM Reps': int(fm_reps),
        'Ansatz': ans_name,
        'Ans Reps': int(ans_reps),
        'Optimizer': opt_name,
        'Accuracy (%)': round(accuracy, 2)
    })

# Create DataFrame and sort by accuracy (descending)
results_df = pd.DataFrame(results)
results_df = results_df.sort_values('Accuracy (%)', ascending=False).reset_index(drop=True)

results_df
# Out:
#    Feature Map  FM Reps    Ansatz  Ans Reps  Optimizer  Accuracy (%)
# 0            Z        2  TwoLocal         1    SPSA500         65.96
# 1           ZZ        1    EffSU2         1  COBYLA300         61.70
# 2            Z        2    EffSU2         2  COBYLA300         61.70
# 3           ZZ        2  RealAmps         1    SPSA500         59.57
# 4            Z        2  RealAmps         1    SPSA500         59.57
# 5            Z        2  RealAmps         1  COBYLA300         59.57
# 6            Z        2  TwoLocal         2    SPSA500         59.57
# 7           ZZ        1  RealAmps         1  COBYLA300         59.57
# 8           ZZ        1  TwoLocal         2  COBYLA300         59.57
# 9           ZZ        2  RealAmps         1  COBYLA300         59.57
# 10          ZZ        1    EffSU2         2  COBYLA300         57.45
# 11          ZZ        1  RealAmps         2    SPSA500         57.45
# 12          ZZ        2    EffSU2         2  COBYLA300         57.45
# 13           Z        1    EffSU2         2  COBYLA300         57.45
# 14           Z        2  RealAmps         2  COBYLA300         55.32
# 15          ZZ        2    EffSU2         1    SPSA500         55.32
# 16          ZZ        2  RealAmps         2  COBYLA300         55.32
# 17          ZZ        1  RealAmps         1    SPSA500         55.32
# 18           Z        1  RealAmps         1  COBYLA300         55.32
# 19           Z        1  RealAmps         1    SPSA500         55.32
# 20          ZZ        2  TwoLocal         1  COBYLA300         55.32
# 21          ZZ        1  TwoLocal         1    SPSA500         53.19
# 22          ZZ        1  TwoLocal         1  COBYLA300         53.19
# 23           Z        1  RealAmps         2  COBYLA300         53.19
# 24           Z        1  RealAmps         2    SPSA500         53.19
# 25           Z        2    EffSU2         2    SPSA500         53.19
# 26          ZZ        2  TwoLocal         2    SPSA500         53.19
# 27           Z        1  TwoLocal         2  COBYLA300         51.06
# 28          ZZ        1  RealAmps         2  COBYLA300         51.06
# 29           Z        2  TwoLocal         2  COBYLA300         51.06
# 30          ZZ        2    EffSU2         2    SPSA500         51.06
# 31          ZZ        2  TwoLocal         2  COBYLA300         48.94
# 32           Z        1  TwoLocal         1  COBYLA300         48.94
# 33           Z        1    EffSU2         1    SPSA500         48.94
# 34           Z        1    EffSU2         2    SPSA500         46.81
# 35          ZZ        1    EffSU2         2    SPSA500         46.81
# 36           Z        1    EffSU2         1  COBYLA300         46.81
# 37           Z        1  TwoLocal         1    SPSA500         46.81
# 38          ZZ        1  TwoLocal         2    SPSA500         46.81
# 39          ZZ        2  RealAmps         2    SPSA500         46.81
# 40           Z        1  TwoLocal         2    SPSA500         44.68
# 41          ZZ        2  TwoLocal         1    SPSA500         44.68
# 42          ZZ        1    EffSU2         1    SPSA500         44.68
# 43           Z        2  RealAmps         2    SPSA500         42.55
# 44           Z        2    EffSU2         1    SPSA500         42.55
# 45           Z        2  TwoLocal         1  COBYLA300         38.30
# 46           Z        2    EffSU2         1  COBYLA300         34.04
# 47          ZZ        2    EffSU2         1  COBYLA300         31.91
